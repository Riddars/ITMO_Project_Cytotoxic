# %% [markdown]
# <a href="https://colab.research.google.com/github/Riddars/ITMO_Project_Cytotoxic/blob/%D0%92%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D1%8F/All_description_Without_Extrim_vaules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Замените 'data' на вашу переменную с данными и 'column_name' на имя столбца
DataFrame = pd.read_csv('https://raw.githubusercontent.com/Riddars/ITMO_Project_Cytotoxic/main/Data/All_descriptors_dataset.csv')

# %%
DataFrame.head()
# Out:
#   Cell type test material  time (hr)  concentration (ug/ml)  viability (%)  \
# 0      143B  MTT       Au          4                  200.0         36.126
# 1      143B  MTT       Au          4                  400.0         22.253
# 2      143B  MTT       Au          4                  500.0         19.643
# 3      143B  MTT       Au         72                    1.0         91.262
# 4      143B  MTT       Au         72                    3.0         87.500
#
#    Hydrodynamic diameter (nm)  Zeta potential (mV)    CID Canonical Smiles  \
# 0                        24.6                -4.65  23985             [Au]
# 1                        24.6               -33.33  23985             [Au]
# 2                        24.6               -31.30  23985             [Au]
# 3                        24.6               -16.95  23985             [Au]
# 4                        24.6                29.45  23985             [Au]
#
# ...

# %%
print(filtered_data.head())

# %%
# Фильтрация данных
filtered_data = DataFrame[DataFrame['viability (%)'] <= 150]
filtered_data = DataFrame[DataFrame['concentration (ug/ml)'] <= 1000]
filtered_data = DataFrame[DataFrame['Zeta potential (mV)'] >= -50]
filtered_data = DataFrame[DataFrame['Hydrodynamic diameter (nm)'] <= 400]

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2865 entries, 0 to 2963
# Data columns (total 61 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Cell type                        2865 non-null   object
#  1   test                             2865 non-null   object
#  2   material                         2865 non-null   object
#  3   time (hr)                        2865 non-null   int64
#  4   concentration (ug/ml)            2865 non-null   float64
#  5   viability (%)                    2865 non-null   float64
#  6   Hydrodynamic diameter (nm)       2865 non-null   float64
#  7   Zeta potential (mV)              2865 non-null   float64
#  8   CID                              2865 non-null   int64
#  9   Canonical Smiles                 2865 non-null   object
#  10  exactmw                          2865 non-null   float64
#  11  amw                              2865 non-null   float64
# ...

# %%
# Подсчитайте количество значений, попадающих в диапазон
количество_значений = DataFrame[(DataFrame['Hydrodynamic diameter (nm)'] >= 400) & (DataFrame['Hydrodynamic diameter (nm)'] <= 1000)].shape[0]

print(f'Количество значений в диапазоне от {400} до {1000}: {количество_значений}')
# Out:
# Количество значений в диапазоне от 400 до 1000: 99

# %%
plt.figure(figsize=(10, 6))
plt.scatter(range(len(filtered_data['Hydrodynamic diameter (nm)'])), filtered_data['Hydrodynamic diameter (nm)'], color='blue', alpha=0.7)
plt.xlabel('Индексы строк')
plt.ylabel('Выживаемость (%)')
plt.title('Точечный график выживаемости')
plt.show()

# %%
filtered_data.to_csv('filtered_dataset_All_Decription.csv', index=False)
